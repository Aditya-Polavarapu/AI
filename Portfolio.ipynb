# %%
import IPython

html_code = """
<!DOCTYPE html>
<html lang='en'>
<head>
    <meta charset='UTF-8'>
    <meta name='viewport' content='width=device-width, initial-scale=1.0'>
    <title>Premium Portfolio</title>
    <style>
        :root {
            --primary: #fbbf24; /* Amber/Gold */
            --primary-glow: rgba(251, 191, 36, 0.3);
            --bg: #020617;
            --card-bg: rgba(30, 41, 59, 0.7);
            --nav-bg: rgba(2, 6, 23, 0.8);
        }

        body {
            font-family: 'Inter', system-ui, sans-serif;
            margin: 0;
            background: #020617;
            color: #f8fafc;
            min-height: 100vh;
            display: flex;
            flex-direction: column;
            padding-top: 70px;
            overflow-x: hidden;
        }

        /* Animated Background Elements */
        body::before {
            content: '';
            position: fixed;
            top: 0; left: 0; width: 100%; height: 100%;
            background: radial-gradient(circle at 50% 50%, #1e1b4b 0%, #020617 100%);
            z-index: -1;
        }

        /* Navigation */
        nav {
            position: fixed;
            top: 0; left: 0; right: 0;
            height: 70px;
            background: var(--nav-bg);
            backdrop-filter: blur(20px);
            border-bottom: 1px solid rgba(251, 191, 36, 0.1);
            display: flex;
            align-items: center;
            justify-content: space-between;
            padding: 0 10%;
            z-index: 2000;
        }
        .nav-logo {
            font-weight: 900;
            font-size: 1.6rem;
            letter-spacing: -1px;
            color: var(--primary);
            text-shadow: 0 0 15px var(--primary-glow);
        }
        .nav-links {
            display: flex;
            gap: 2.5rem;
        }
        .nav-links a {
            color: #94a3b8;
            text-decoration: none;
            font-weight: 600;
            position: relative;
            transition: color 0.3s;
        }
        .nav-links a:hover { color: var(--primary); }
        .nav-links a::after {
            content: '';
            position: absolute;
            width: 0; height: 2px;
            bottom: -5px; left: 0;
            background: var(--primary);
            transition: width 0.3s;
        }
        .nav-links a:hover::after { width: 100%; }

        /* Header & Content */
        header {
            padding: 6rem 2rem 4rem;
            text-align: center;
            animation: fadeInDown 1s ease-out;
        }
        h1 {
            font-size: 4rem;
            margin: 0;
            color: white;
            text-shadow: 0 0 30px rgba(255,255,255,0.1);
        }
        .accent { color: var(--primary); }

        .container {
            padding: 0 2rem 5rem;
            max-width: 1000px;
            margin: auto;
        }

        .reveal {
            opacity: 0;
            transform: translateY(30px);
            transition: all 0.8s ease-out;
        }
        .reveal.active {
            opacity: 1;
            transform: translateY(0);
        }

        .card {
            background: var(--card-bg);
            backdrop-filter: blur(10px);
            border: 1px solid rgba(255,255,255,0.05);
            padding: 3rem;
            border-radius: 32px;
            margin-bottom: 2.5rem;
            box-shadow: 0 25px 50px -12px rgba(0,0,0,0.5);
            transition: border 0.3s, transform 0.3s;
        }
        .card:hover {
            border: 1px solid rgba(251, 191, 36, 0.3);
            transform: scale(1.01);
        }

        .skill-badge {
            background: rgba(251, 191, 36, 0.1);
            color: var(--primary);
            padding: 10px 24px;
            border-radius: 16px;
            font-weight: 700;
            border: 1px solid rgba(251, 191, 36, 0.2);
            transition: all 0.4s cubic-bezier(0.175, 0.885, 0.32, 1.275);
        }
        .skill-badge:hover {
            background: var(--primary);
            color: var(--bg);
            transform: rotate(-3deg) scale(1.1);
            box-shadow: 0 10px 20px var(--primary-glow);
        }

        /* Advanced Chat */
        #chat-container {
            position: fixed;
            bottom: 30px; right: 30px;
            width: 380px;
            background: #0f172a;
            border: 1px solid rgba(251, 191, 36, 0.2);
            border-radius: 24px;
            box-shadow: 0 20px 40px rgba(0,0,0,0.6);
            display: flex;
            flex-direction: column;
            overflow: hidden;
            z-index: 1000;
        }
        #chat-header {
            background: #1e293b;
            padding: 20px;
            border-bottom: 1px solid rgba(255,255,255,0.05);
            display: flex;
            align-items: center;
            gap: 12px;
        }
        .status-dot {
            width: 12px; height: 12px;
            background: #10b981;
            border-radius: 50%;
            box-shadow: 0 0 10px #10b981;
            animation: pulse 2s infinite;
        }

        #chat-messages {
            height: 300px;
            overflow-y: auto;
            padding: 20px;
            background: linear-gradient(to bottom, transparent, rgba(251, 191, 36, 0.02));
        }
        .msg {
            margin-bottom: 15px;
            padding: 12px 18px;
            border-radius: 18px;
            max-width: 85%;
            font-size: 0.95rem;
        }
        .msg.ai { background: rgba(255,255,255,0.05); color: #cbd5e1; border-bottom-left-radius: 4px; }
        .msg.user { background: var(--primary); color: #020617; font-weight: 600; align-self: flex-end; margin-left: auto; border-bottom-right-radius: 4px; }

        #chat-input-area {
            padding: 20px;
            display: flex;
            gap: 10px;
            background: rgba(0,0,0,0.2);
        }
        #chat-input {
            flex: 1;
            background: #1e293b;
            border: 1px solid rgba(255,255,255,0.1);
            padding: 12px 18px;
            border-radius: 14px;
            color: white;
            outline: none;
        }
        #chat-send {
            background: var(--primary);
            border: none; padding: 0 20px;
            border-radius: 14px;
            cursor: pointer;
            font-weight: bold;
        }

        @keyframes pulse { 0% { opacity: 1; } 50% { opacity: 0.4; } 100% { opacity: 1; } }
        @keyframes fadeInDown { from { opacity: 0; transform: translateY(-20px); } to { opacity: 1; transform: translateY(0); } }
    </style>
</head>
<body>

<nav>
    <div class='nav-logo'>PRO.<span class='accent'>FILE</span></div>
    <div class='nav-links'>
        <a href='#'>Index</a>
        <a href='#'>Works</a>
        <a href='#'>Connect</a>
    </div>
</nav>

<header>
    <h1>I am <span class='accent'>[Your Name]</span></h1>
    <p style='color: #64748b; font-size: 1.4rem; margin-top: 1rem;'>Building high-performance digital solutions</p>
</header>

<div class='container'>
    <div class='card reveal'>
        <h2 class='accent'>Overview</h2>
        <p style='color: #94a3b8; line-height: 1.8; font-size: 1.1rem;'>I specialize in bridging the gap between complex data and intuitive user interfaces. Check back tomorrow for my full biography.</p>
    </div>

    <div class='card reveal'>
        <h2 class='accent'>Core Technologies</h2>
        <div class='skills' style='display:flex; gap:15px; flex-wrap:wrap; margin-top:1.5rem;'>
            <span class='skill-badge'>Python</span>
            <span class='skill-badge'>PyTorch</span>
            <span class='skill-badge'>Next.js</span>
            <span class='skill-badge'>Docker</span>
            <span class='skill-badge'>GraphQL</span>
        </div>
    </div>
</div>

<div id='chat-container'>
    <div id='chat-header'>
        <div class='status-dot'></div>
        <div style='font-weight: 700; color: white;'>System Assistant</div>
    </div>
    <div id='chat-messages' style='display: flex; flex-direction: column;'>
        <div class='msg ai'>System online. How can I assist you regarding [Your Name]'s expertise?</div>
    </div>
    <div id='chat-input-area'>
        <input type='text' id='chat-input' placeholder='Enter query...'>
        <button id='chat-send'>→</button>
    </div>
</div>

<script>
    // Scroll Reveal Logic
    function reveal() {
        var reveals = document.querySelectorAll(".reveal");
        reveals.forEach(r => {
            var windowHeight = window.innerHeight;
            var elementTop = r.getBoundingClientRect().top;
            if (elementTop < windowHeight - 100) r.classList.add("active");
        });
    }
    window.addEventListener("scroll", reveal);
    window.onload = reveal;

    const sendBtn = document.getElementById('chat-send');
    const input = document.getElementById('chat-input');
    const messages = document.getElementById('chat-messages');

    function addMessage(text, isUser) {
        const div = document.createElement('div');
        div.className = 'msg ' + (isUser ? 'user' : 'ai');
        div.textContent = text;
        messages.appendChild(div);
        messages.scrollTop = messages.scrollHeight;
    }

    sendBtn.onclick = () => {
        const val = input.value.trim();
        if (!val) return;
        addMessage(val, true);
        input.value = '';
        setTimeout(() => {
            addMessage("Query received. Data for '" + val + "' will be accessible once the main database is synced tomorrow.", false);
        }, 600);
    };
    input.onkeypress = (e) => { if(e.key === 'Enter') sendBtn.onclick(); };
</script>

</body>
</html>
"""

IPython.display.HTML(html_code)
